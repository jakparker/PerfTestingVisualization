# %%
import pandas
from IPython.display import display

def shiftTimeStamp(row):
    return row['timeStamp'] - 1688695066761


df = pandas.read_csv('logs_dress_all2.csv')
df['modTimeStamp'] = df.apply(shiftTimeStamp, axis=1)
display(df)
# Out:
#            timeStamp  elapsed                    label  responseCode  \
# 0      1688695066761     1707    RTSA_GetDetails_Token           200
# 1      1688695068505       89  Sales_OrderImport_Token           200
# 2      1688695068596      399        TnT Token Request           200
# 3      1688695069622     3933  BG_LOAD_RTSA_GetDetails           200
# 4      1688695069634      326      BG_LOAD_TnT_Enquiry           200
# ...              ...      ...                      ...           ...
# 33374  1688700468695     1474  BG_LOAD_RTSA_GetDetails           200
# 33375  1688700468746     1413  BG_LOAD_RTSA_GetDetails           200
# 33376  1688700469033       70      BG_LOAD_TnT_Enquiry           200
# 33377  1688700469333       69      BG_LOAD_TnT_Enquiry           200
# 33378  1688700469483     1868       BG_Load_SalesOrder           201
#
#       responseMessage           threadName dataType  success  failureMessage  \
# ...

# %%
import matplotlib.pyplot as plt

# %%
print(df.columns)
# Out:
# Index(['timeStamp', 'elapsed', 'label', 'responseCode', 'responseMessage',
#        'threadName', 'dataType', 'success', 'failureMessage', 'bytes',
#        'sentBytes', 'grpThreads', 'allThreads', 'URL', 'Latency', 'IdleTime',
#        'Connect'],
#       dtype='object')

# %%
df.plot('modTimeStamp', 'elapsed',   kind='line', logx=True)
# Out:
# <Axes: xlabel='modTimeStamp'>
